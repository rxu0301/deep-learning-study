# %%
# !pip install pandas==1.5.3
# !pip install seaborn==0.12.2

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
data = pd.read_csv('dataset/iris3.csv')
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
x = data.iloc[:,0:4].values
y = data.iloc[:,4].values

# %%
y = pd.get_dummies(y)
y
# Out:
#      Iris-setosa  Iris-versicolor  Iris-virginica
# 0              1                0               0
# 1              1                0               0
# 2              1                0               0
# 3              1                0               0
# 4              1                0               0
# ..           ...              ...             ...
# 145            0                0               1
# 146            0                0               1
# 147            0                0               1
# 148            0                0               1
# 149            0                0               1
#
# [150 rows x 3 columns]

# %%
# 모델 생성

model =Sequential()
model.add(Dense(12,input_shape=(4,),activation='relu',name='Dense01'))
model.add(Dense(8,activation='relu',name='Dense02'))
model.add(Dense(3,activation='softmax',name='Dense03'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  Dense01 (Dense)             (None, 12)                60
#
#  Dense02 (Dense)             (None, 8)                 104
#
#  Dense03 (Dense)             (None, 3)                 27
#
# ...
# Total params: 191
# Trainable params: 191
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='CategoricalCrossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history = model.fit(x, y, epochs=100, batch_size=5)
# Out:
# Epoch 1/100
# 30/30 [==============================] - 2s 4ms/step - loss: 1.1021 - accuracy: 0.3333
# Epoch 2/100
# 30/30 [==============================] - 0s 3ms/step - loss: 1.0373 - accuracy: 0.3867
# Epoch 3/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.9887 - accuracy: 0.8200
# Epoch 4/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.9345 - accuracy: 0.7667
# Epoch 5/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.8760 - accuracy: 0.8267
# Epoch 6/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.8257 - accuracy: 0.8600
# Epoch 7/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7823 - accuracy: 0.8867
# Epoch 8/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.7575 - accuracy: 0.7933
# Epoch 9/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7253 - accuracy: 0.8867
# Epoch 10/100
# ...

# %%
print("Accuracy : %4f" % (model.evaluate(x, y))[1])
# Out:
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1346 - accuracy: 0.9733
# Accuracy : 0.973333

# %%
m ,acc = model.evaluate(x, y)
print('정확도 : %.2f' %(acc*100))
print(m)
# Out:
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1346 - accuracy: 0.9733
# 정확도 : 97.33
# 0.1346399337053299

# %%
# 새로운 데이터로 예측하기

new_flower = np.array([[5.1,3.5,1.4,0.2]])

pred = model.predict(new_flower)
s = ['setosa','versicolor','virginica']
pred_s = s[np.argmax(pred)]

print("예측 후보 :",s)
print('예측 확률 :',pred)
print("예측 결과 :",pred_s)
# Out:
# 1/1 [==============================] - 0s 7ms/step
# 예측 후보 : ['setosa', 'versicolor', 'virginica']
# 예측 확률 : [[9.9961865e-01 3.8129970e-04 6.6923818e-09]]
# 예측 결과 : setosa

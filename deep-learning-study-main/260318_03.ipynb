# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
df = pd.read_csv('dataset/sonar3.csv',header=None)  # num 60 = 0(암석)/1(광석)
df.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   0
# 1  0.0052  0.0044   0
# 2  0.0095  0.0078   0
# ...

# %%
X = df.iloc[:,0:60].values
y = df.iloc[:,60].values

# %%
model =Sequential()
model.add(Dense(24,input_shape=(60,),activation='relu',name='input'))
model.add(Dense(10,activation='relu',name='hidden'))
model.add(Dense(1,activation='sigmoid',name='output'))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input (Dense)               (None, 24)                1464
#
#  hidden (Dense)              (None, 10)                250
#
#  output (Dense)              (None, 1)                 11
#
# ...
# Total params: 1,725
# Trainable params: 1,725
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.fit(x,y,epochs=200,batch_size=10)
# Out:
# Epoch 1/200
# 21/21 [==============================] - 0s 6ms/step - loss: 0.6915 - accuracy: 0.5385
# Epoch 2/200
# 21/21 [==============================] - 0s 6ms/step - loss: 0.6812 - accuracy: 0.5769
# Epoch 3/200
# 21/21 [==============================] - 0s 6ms/step - loss: 0.6731 - accuracy: 0.6154
# Epoch 4/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.6667 - accuracy: 0.6442
# Epoch 5/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.6615 - accuracy: 0.7115
# Epoch 6/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.6510 - accuracy: 0.6971
# Epoch 7/200
# 21/21 [==============================] - 0s 5ms/step - loss: 0.6324 - accuracy: 0.7019
# Epoch 8/200
# 21/21 [==============================] - 0s 6ms/step - loss: 0.6154 - accuracy: 0.7308
# Epoch 9/200
# 21/21 [==============================] - 0s 6ms/step - loss: 0.6021 - accuracy: 0.7596
# Epoch 10/200
# ...

# %%
loss, acc = model.evaluate(x,y)
print("정확도 :",acc*100)
# Out:
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0396 - accuracy: 0.9952
# 정확도 : 99.5192289352417

# %%
# !pip install scikit-learn==1.6.1

# %%
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('dataset/sonar3.csv',header=None)  # num[column=60] = 0(암석)/1(광석)
df.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   0
# 1  0.0052  0.0044   0
# 2  0.0095  0.0078   0
# ...

# %%
x = df.iloc[:,0:60].values
y = df.iloc[:,60].values

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.3,shuffle=True)

# %%
model =Sequential()
model.add(Dense(24,input_shape=(60,),activation='relu',name='input'))
model.add(Dense(10,activation='relu',name='hidden'))
model.add(Dense(1,activation='sigmoid',name='output'))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input (Dense)               (None, 24)                1464
#
#  hidden (Dense)              (None, 10)                250
#
#  output (Dense)              (None, 1)                 11
#
# ...
# Total params: 1,725
# Trainable params: 1,725
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.fit(X_train,y_train,epochs=200,batch_size=10)
# Out:
# Epoch 1/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6935 - accuracy: 0.5379
# Epoch 2/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6849 - accuracy: 0.5448
# Epoch 3/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6798 - accuracy: 0.5793
# Epoch 4/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6742 - accuracy: 0.6276
# Epoch 5/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6682 - accuracy: 0.6483
# Epoch 6/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6639 - accuracy: 0.6690
# Epoch 7/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6538 - accuracy: 0.6621
# Epoch 8/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6449 - accuracy: 0.6690
# Epoch 9/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6350 - accuracy: 0.6759
# Epoch 10/200
# ...

# %%
loss, acc = model.evaluate(X_test,y_test)
print("정확도 :",acc*100)
# Out:
# 2/2 [==============================] - 0s 4ms/step - loss: 0.7204 - accuracy: 0.8413
# 정확도 : 84.1269850730896

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import KFold

df = pd.read_csv('dataset/sonar3.csv', header=None)

X = df.iloc[:, 0:60]
y = df.iloc[:, 60]

k = 5
kfold = KFold(n_splits=k, shuffle=True, random_state=42)
acc_score = []

def model_fn():
    model = Sequential()
    model.add(Dense(24, input_shape=(60,), activation='relu', name='input'))
    model.add(Dense(10, activation='relu', name='hidden'))
    model.add(Dense(1, activation='sigmoid', name='output'))
    return model
    
for train_idx, test_idx in kfold.split(X):
    X_train, X_test = X.iloc[train_idx, :], X.iloc[test_idx, :]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

    model = model_fn()
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    model.fit(X_train, y_train, epochs=200, batch_size=10, verbose=0)

    loss, acc = model.evaluate(X_test, y_test, verbose=0)
    acc_score.append(acc)


acc_avg = sum(acc_score) / k
print('정확도:', acc_score)
print('정확도 평균:', acc_avg)
# Out:
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_test_function.<locals>.test_function at 0x000002615FA58160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

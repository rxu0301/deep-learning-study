# %% [markdown]
# # 1. Matplotlib 개요

# %% [markdown]
# <img src="https://i.imgur.com/yYJQ2hc.png" width="600px" />

# %% [markdown]
# ## 1.1 Matplotlib 정의

# %% [markdown]
# - Matplotlib는 Python의 데이터를 차트(chart)나 플롯(plot)으로 시각화(visulaization)하는 라이브러리.
#
# - https://matplotlib.org/

# %% [markdown]
# <img src="https://miro.medium.com/max/1350/1*OAFEIg9w1XHyZk0xBud14A.png" width="600px" />

# %% [markdown]
# ## 1.2 Matplotlib 주요 그래프
#
# - 라인 플롯 (line plot)
# - 바 플롯 (bar plot)
# - 스캐터 플롯 (scatter plot)
# - 컨투어 플롯 (contour plot)  - 등고선
# - 서피스 플롯 (surface plot)
# - 히스토그램 (histogram)
# - 박스 플롯 (box plot)
#
# - https://matplotlib.org/stable/gallery/index.html

# %% [markdown]
# 라인 플롯 (line plot)

# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.array([1,2,3,4])
y = x ** 2

plt.plot(x, y)   # 라인 플롯

plt.show()

# %% [markdown]
# 바 플롯 (bar plot)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]

plt.bar(x, values)    # 바(bar) plot
plt.xticks(x, years)

plt.show()

# %% [markdown]
# 스캐터 플롯 (scatter plot)

# %%
import matplotlib.pyplot as plt
import numpy as np

N = 100
r0 = 0.6
x = 0.9 * np.random.rand(N)
y = 0.9 * np.random.rand(N)
area = (20 * np.random.rand(N))**2 
c = np.sqrt(area)
r = np.sqrt(x ** 2 + y ** 2)
area1 = np.ma.masked_where(r < r0, area)
area2 = np.ma.masked_where(r >= r0, area)

plt.scatter(x, y, s=area1, marker='^', c=c)   # scatter 플롯 설정
plt.scatter(x, y, s=area2, marker='o', c=c)   # scatter 플롯 설정

theta = np.arange(0, np.pi / 2, 0.01)
plt.plot(r0 * np.cos(theta), r0 * np.sin(theta))

plt.show()

# %% [markdown]
# 컨투어 플롯 (contour plot) - 등고선

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import ma
from matplotlib import ticker, cm

N = 100
x = np.linspace(-3.0, 3.0, N)
y = np.linspace(-2.0, 2.0, N)

X, Y = np.meshgrid(x, y)

Z1 = np.exp(-X**2 - Y**2)
Z2 = np.exp(-(X * 10)**2 - (Y * 10)**2)
z = Z1 + 50 * Z2

z[:5, :5] = -1

z = ma.masked_where(z <= 0, z)


fig, ax = plt.subplots()
cs = ax.contourf(X, Y, z, locator=ticker.LogLocator(), cmap=cm.PuBu_r)   # 컨투어(contour) plot

cbar = fig.colorbar(cs)

plt.show()

# %% [markdown]
# 서피스 플롯 (surface plot)

# %%
import matplotlib.pyplot as plt
import numpy as np


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

r = np.linspace(0, 1.25, 50)
p = np.linspace(0, 2*np.pi, 50)
R, P = np.meshgrid(r, p)
Z = ((R**2 - 1)**2)

X, Y = R*np.cos(P), R*np.sin(P)

ax.plot_surface(X, Y, Z, cmap=plt.cm.YlGnBu_r)     # 서피스(surface) plot

ax.set_zlim(0, 1)
ax.set_xlabel(r'$\phi_\mathrm{real}$')
ax.set_ylabel(r'$\phi_\mathrm{im}$')
ax.set_zlabel(r'$V(\phi)$')

plt.show()

# %% [markdown]
# 히스토그램 (histogram)

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

mu = 100  
sigma = 15 
x = mu + sigma * np.random.randn(437)

num_bins = 50

fig, ax = plt.subplots()

n, bins, patches = ax.hist(x, num_bins, density=True)   # 히스토그램(hist) plot

y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
ax.plot(bins, y, '--')

fig.tight_layout()
plt.show()

# %% [markdown]
# 박스 플롯 (box plot)

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)

spread = np.random.rand(50) * 100
center = np.ones(25) * 50
flier_high = np.random.rand(10) * 100 + 100
flier_low = np.random.rand(10) * -100
data = np.concatenate((spread, center, flier_high, flier_low))

fig1, ax1 = plt.subplots()
ax1.set_title('Basic Plot')
ax1.boxplot(data)     # 박스(box) plot

plt.show()

# %% [markdown]
# ## 1.3 Matplotlib 용어
#
# - Figure : 그래프 전체 그림. 가장 큰 개념
# - Axes : 그래프가 그려지는 좌표 평면. 한개의 Figure 에 여러개의 Axes 가 올 수 있음.
# - X axis : X 축.
# - Y axis : Y 축.
# - Tick : 눈금. Major 눈금과 Minor 눈금이 있음.
# - Spines : 그래프 테두리.
# - Line : 선 그래프(line plot)의 선.
# - Markers : 산점도(scatter)에서 점.
# - Grid : 그래프 격자.
# - Title : 그래프 제목.
# - Label : 각 축이나 눈금 등에 붙이는 Text.
# - Legend : 범례, 각 그래프의 이름(label)을 알기 쉽게 별도로 표시해 놓는 것.

# %% [markdown]
# <img src="https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FrBMDG%2FbtqC85CFVwA%2FlNq62sctyn5kj1FpJQ6UGk%2Fimg.png" width="600px" />

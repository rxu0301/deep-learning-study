# %%
b = """
홍길동 : 1234, Gil-Dong Hong,
이길동 : 3915, Gil-Dong Lee,
박길동 : 0000, Gil-Dong Park
"""
print(b)
# Out:
# 홍길동: 1234, Gil-Dong Hong,
# 이길동: 3915, Gil-Dong Lee,
# 박길동: 0000, Gil-Dong Park

# %%
 b = b.strip()
 print(b)
# Out:
# 홍길동: 1234, Gil-Dong Hong,
# 이길동: 3915, Gil-Dong Lee,
# 박길동: 0000, Gil-Dong Park

# %%
for i in b.split(':'):
  data = i
  i = i[0]
  print(data)
# Out:
# 홍길동
#  1234, Gil-Dong Hong,
# 이길동
#  3915, Gil-Dong Lee,
# 박길동
#  0000, Gil-Dong Park

# %%
b = """
홍길동 : 1234, Gil-Dong Hong,
이길동 : 3915, Gil-Dong Lee,
박길동 : 0000, Gil-Dong Park
"""

for i in b:
  i = i.split(':')
  i = i[0].strip()
  print(i)
# Out:
# 홍
# 길
# 동
#
#
#
# 1
# 2
# 3
# 4
# ,
#
# G
# i
# l
# -
# D
# o
# n
# g
#
# H
# o
# n
# g
# ,
#
# 이
# 길
# 동
#
#
#
# 3
# 9
# 1
# 5
# ,
#
# G
# i
# l
# -
# D
# o
# n
# g
#
# L
# e
# e
# ,
#
# 박
# 길
# 동
#
#
#
# 0
# 0
# 0
# 0
# ,
#
# G
# i
# l
# -
# D
# o
# n
# g
#
# P
# a
# r
# k

# %%
list_sns = []
li ={"alt,href"}

for list_sns in li:
  print(list_sns)
# Out:
# alt,href

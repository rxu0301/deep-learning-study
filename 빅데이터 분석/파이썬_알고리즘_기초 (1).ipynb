# %% [markdown]
# ## **11번**

# %%
a = int(input('원래 볼펜이 몇 개였어?'))
b = int(input('동환이에게 몇 개를 줬어?'))
c = str(a-b)
print('동욱이의 볼펜이',c+'개가 남았어요.')
# Out:
# 원래 볼펜이 몇 개였어?10
# 동환이에게 몇 개를 줬어?3
# 동욱이의 볼펜이 7개가 남았어요.

# %% [markdown]
# # **12번**

# %%
a = int(input('민찬아, 첫 번째 숫자 알려줘.'))
b = int(input('민찬아, 두 번째 숫자 알려줘.'))
c = int(input('민찬아, 세 번째 숫자 알려줘.'))
d = str((a+b)*3)
print('더한 두 수에 곱하기를 하면',d+'입니다.')
# Out:
# 민찬아, 첫 번째 숫자 알려줘.1
# 민찬아, 두 번째 숫자 알려줘.2
# 민찬아, 세 번째 숫자 알려줘.3
# 더한 두 수에 곱하기를 하면 9입니다.

# %% [markdown]
# # **13번**

# %%
a = input()  #100초과
b = input()  #10미만
total = str(a.count(b))
print('성률아,',a+'에',b+'이',total+'번 들어가네.')
# Out:
# 100
# 7
# 성률아, 100에 7이 0번 들어가네.

# %% [markdown]
# # **14번**

# %%
total_money = 0
money = int(input())
friend = int(input())
total_money = str(money//friend)
money = str(money)
print('얘들아, 총',money+'원이니까',total_money+'원씩 내.')
# Out:
# 10000
# 10
# 얘들아, 총 10000원이니까 1000.0원씩 내.

# %% [markdown]
# # **15번**

# %%
km = float(input())
mile = str(km *0.62)
print('세인이 집부터 학교까지',mile+'마일이구나')
# Out:
# 10
# 세인이 집부터 학교까지 6.2마일이구나

# %% [markdown]
# # **16번**

# %%
kg = int(input())
pound = str(kg*2.204)
print('현이의 몸무게는',pound+'파운드구나')
# Out:
# 10
# 현이의 몸무게는 22.040000000000003파운드구나

# %% [markdown]
# # **17번**

# %%
inch = int(input())
cm = str(inch*2.54)
print('지우는',cm+'센티미터 지곱 넓이의 피자를 먹었구나.')
# Out:
# 100
# 지우는 254.0센티미터 지곱 넓이의 피자를 먹었구나.

# %% [markdown]
# # **18번**

# %%
pyeong = int(input())
m = str(pyeong *3.3058)
print('지원이는 오늘',m+'제곱미터를 청소했구나.')
# Out:
# 10
# 지원이는 오늘 33.058제곱미터를 청소했구나.

# %% [markdown]
# # **19번**

# %%
bread1 = int(input())
bread2 = int(input())
if bread1 > bread2:
  print('더 많은 든 바구니의 빵은',str(bread1)+'개입니다.')
else:
  print('더 많은 든 바구니의 빵은',str(bread2)+'개입니다.')
# Out:
# 1
# 10
# 더 많은 든 바구니의 빵은 10개입니다.

# %% [markdown]
# # **20번**

# %%
bread1 = '1'
bread2 = '2'
bread1_num = int(input())
bread2_num = int(input())
total = 0
if bread1_num > bread2_num:
  total = bread1_num-bread2_num
  print(str(bread1)+'번 바구니 빵이',str(total)+'개 더 많습니다.')
else:
  total = bread2_num-bread1_num
  print(str(bread2)+'번 바구니 빵이',str(total)+'개 더 많습니다.')
# Out:
# 10
# 2
# 1번 바구니 빵이 8개 더 많습니다.

# %% [markdown]
# # **21번**

# %%
input1 = int(input())
total = 5000
if total <input1:
  print('초과했어')
elif total > input1:
  print('모자라')
# Out:
# 10
# 모자라

# %% [markdown]
# # **22번**

# %%
a = int(input())
if a<15:
  print('추워요.')
elif a>20:
  print('더워요.')
elif 15<=a and a<=25:
  print('적당합니다.')
# Out:
# 23
# 더워요.

# %% [markdown]
# # **23번**

# %%
a = input()
if a == '노랑':
  print('나도 그래')
else:
  print('나는 그 색 말고 노랑이 좋아')
# Out:
# 초록
# 나는 그 색 말고 노랑이 좋아

# %% [markdown]
# # **24번**

# %%
a = input()
if a =='응':
  print('우산 잊지마')
elif a == '아니':
  print('우산 없이 가도 되겠네')
# Out:
# 아니
# 우산 없이 가도 되겠네

# %% [markdown]
# # **25번**

# %%
a = int(input())
if a == 1:
  print('볼펜')
elif a== 2:
  print('노트')
elif a==3:
  print('가방')
# Out:
# 2
# 노트

# %% [markdown]
# # **26번**

# %%
a = input('성 입력')
b = input('이름 입력')
c = a+' '+b
print(c)
print(len(c))
# Out:
# 성 입력박
# 이름 입력태윤
# 박 태윤
# 4

# %% [markdown]
# # **27번**

# %%
a = input()
print(len(a))
# Out:
# 오늘은 어린이날 우리들 세상
# 15

# %% [markdown]
# # **28번**

# %%
a = int(input())
b = a*2
print(b)
print(type(b))
# Out:
# 4
# 8
# <class 'int'>

# %% [markdown]
# # **29번**

# %%
arr = ['파주시','포천시','가평군']
print(arr)
arr.append(input())
print(arr)
# Out:
# ['파주시', '포천시', '가평군']
# 의성군
# ['파주시', '포천시', '가평군', '의성군']

# %% [markdown]
# # **30번**

# %%
arr = ['파주시','포천시','가평군']
arr.sort()
arr.reverse()
print(arr)
# Out:
# ['포천시', '파주시', '가평군']

# %% [markdown]
# # **31번**

# %%
arr = ['파주시','포천시','가평군']
print(arr)
arr.remove(input())
print(arr)
arr.clear()
print(arr)
# Out:
# ['파주시', '포천시', '가평군']
# 가평군
# ['파주시', '포천시']
# []

# %% [markdown]
# # **32번**

# %%
arr = ('의성읍','접곡면','사곡면')
print(arr)
arr1 = ('금성면','다인면')
print(arr1)
print(arr+arr1)
# Out:
# ('의성읍', '접곡면', '사곡면')
# ('금성면', '다인면')
# ('의성읍', '접곡면', '사곡면', '금성면', '다인면')

# %% [markdown]
# # **33번**

# %%
arr = {'지우개','볼펜','비타민','연필','사탕'}
print(arr)
# Out:
# {'볼펜', '연필', '사탕', '비타민', '지우개'}

# %% [markdown]
# # **34번**

# %%
arr = set()

arr.add('쿠폰')

arr.update(['지우개','쿠폰','사탕'])
print(arr)
# Out:
# {'쿠폰', '사탕', '지우개'}

# %% [markdown]
# # **35번**

# %%
a = {'지우개','쿠폰','사탕'}
print(a)
a.remove('지우개')
print(a)
a.clear()
print(a)
# Out:
# {'쿠폰', '사탕', '지우개'}
# {'쿠폰', '사탕'}
# set()

# %% [markdown]
# # **36번**

# %%
dic = {'이름':'박태윤','취미':'운동','장점':'노력하는 걸 잘한다','지원 동기':'돈 벌어야지'}
print(dic.keys())
print(dic.values())
# Out:
# dict_keys(['이름', '취미', '장점', '지원 동기'])
# dict_values(['박태윤', '운동', '노력하는 걸 잘한다', '돈 벌어야지'])

# %% [markdown]
# # **37번**

# %%
dic = {'이름':'박태윤','취미':'운동','장점':'노력하는 걸 잘한다','지원 동기':'돈 벌어야지'}
print(dic)
# Out:
# {'이름': '박태윤', '취미': '운동', '장점': '노력하는 걸 잘한다', '지원 동기': '돈 벌어야지'}

# %% [markdown]
# # **38번**

# %%
dic = {'이름':'박태윤','취미':'운동','장점':'노력하는 걸 잘한다','지원 동기':'돈 벌어야지'}
print(dic['지원 동기'])
print(dic.get('지원 동기'))
# Out:
# 돈 벌어야지
# 돈 벌어야지

# %% [markdown]
# # **39번**

# %%
dic = {'이름':'박태윤','취미':'운동','장점':'노력하는 걸 잘한다','지원 동기':'돈 벌어야지'}
dic['지원 동기'] = '행복하기 위해서'
print(dic)
dic['관련 인턴 경험'] = '3개월'
print(dic)
# Out:
# {'이름': '박태윤', '취미': '운동', '장점': '노력하는 걸 잘한다', '지원 동기': '행복하기 위해서'}
# {'이름': '박태윤', '취미': '운동', '장점': '노력하는 걸 잘한다', '지원 동기': '행복하기 위해서', '관련 인턴 경험': '3개월'}

# %% [markdown]
# # **40번**

# %%
a = []
print(a)
a = list(a)
print(a)
c=()
print(c)
c = tuple(c)
print(c)
z = set()
print(z)
e = {}
print(e)
e = dict(e)
print(e)
f = set()
# Out:
# []
# []
# ()
# ()
# set()
# {}
# {}

# %% [markdown]
# # **41번**

# %%
arr = ['대한민국','일본','싱가포르','미국']
a = int(input())
print(arr[a-1])
# Out:
# 2
# 일본

# %% [markdown]
# # **42번**

# %%
arr = ('돈','가족','명예')
total = arr.index('가족')
print(total)
print(arr[total])
# Out:
# 1
# 가족

# %% [markdown]
# # **43번**

# %%
arr1 = ['롤','피파']
arr1.append(input())
print(arr1)
# Out:
# 발로란트
# ['롤', '피파', '발로란트']

# %% [markdown]
# # **44번**

# %%
a = 'Mark Zuckerberg'
total = a.count('e')
print(total)
# Out:
# 2

# %% [markdown]
# # **45번**

# %%
for i in range(1,6):
  print(str(i)+'번째 추르를 줄게')
# Out:
# 1번째 추르를 줄게
# 2번째 추르를 줄게
# 3번째 추르를 줄게
# 4번째 추르를 줄게
# 5번째 추르를 줄게

# %% [markdown]
# # **46번**

# %%
a = 8
b = 1
while a<=13 and b<=6:
  print(str(a)+'시입니다.',str(b)+'교시 시작이니까 교실로 들어가세요.')
  a+=1
  b+=1
# Out:
# 8시입니다. 1교시 시작이니까 교실로 들어가세요.
# 9시입니다. 2교시 시작이니까 교실로 들어가세요.
# 10시입니다. 3교시 시작이니까 교실로 들어가세요.
# 11시입니다. 4교시 시작이니까 교실로 들어가세요.
# 12시입니다. 5교시 시작이니까 교실로 들어가세요.
# 13시입니다. 6교시 시작이니까 교실로 들어가세요.

# %% [markdown]
# # **47번**

# %%
idol = ['하니','민지','혜린','다니엘','혜인']
for i in idol:
  print(i+'야, 안녕')
# Out:
# 하니야, 안녕
# 민지야, 안녕
# 혜린야, 안녕
# 다니엘야, 안녕
# 혜인야, 안녕

# %% [markdown]
# # **48번**

# %%
a = int(input())
for i in range(1,11):
  print(a,'*',i,'=',a*i)
# Out:
# 5
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50

# %% [markdown]
# # **49번**

# %%
total = 0
for i in range(3):
  b = int(input())
  total += b
print(total)
# Out:
# 1
# 2
# 3
# 6

# %% [markdown]
# # **50번**

# %%
sum = 0
for i in range(5):
  a = int(input())
  sum +=a
print(sum)
# Out:
# 1
# 2
# 3
# 4
# 5
# 15

# %% [markdown]
# # **51번**

# %%
a = input()
if a == 'up':
  b = int(input())
  for i in range(1,b+1):
    print(i)
elif a == 'down':
  b = int(input())
  for i in range(b,-1,-1):
    print(i)
# Out:
# down
# 8
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 1
# 0

# %% [markdown]
# # **52번**

# %%
def 치즈라면():
  print('물을 끓인다')
  print('면과 소스를 넣는다')
  print('3분이 되면 불을 끈다')
  print('치즈를 올리고 뚜겅을 닫는다')
  print('20초 기다리면 완성')
치즈라면()
# Out:
# 물을 끓인다
# 면과 소스를 넣는다
# 3분이 되면 불을 끈다
# 치즈를 올리고 뚜겅을 닫는다
# 20초 기다리면 완성

# %% [markdown]
# # **53번**

# %%
def 치즈라면(name):
  print(name,'물을 끓인다')
  print(name,'면과 소스를 넣는다')
  print(name,'3분이 되면 불을 끈다')
  print(name,'치즈를 올리고 뚜겅을 닫는다')
  print(name,'20초 기다리면 완성')
치즈라면('박태윤이')
# Out:
# 박태윤이 물을 끓인다
# 박태윤이 면과 소스를 넣는다
# 박태윤이 3분이 되면 불을 끈다
# 박태윤이 치즈를 올리고 뚜겅을 닫는다
# 박태윤이 20초 기다리면 완성

# %% [markdown]
# # **54번**

# %%
def 치즈라면(name,name1):
  print(name,name1,'물을 끓인다')
  print(name,name1,'면과 소스를 넣는다')
  print(name,name1,'파를 넣는다')
  print(name,name1,'3분이 되면 불을 끈다')
  print(name,name1,'치즈를 올리고 뚜겅을 닫는다')
  print(name,name1,'20초 기다리면 완성')
치즈라면('박세인','박태윤')
# Out:
# 박세인 박태윤 물을 끓인다
# 박세인 박태윤 면과 소스를 넣는다
# 박세인 박태윤 파를 넣는다
# 박세인 박태윤 3분이 되면 불을 끈다
# 박세인 박태윤 치즈를 올리고 뚜겅을 닫는다
# 박세인 박태윤 20초 기다리면 완성

# %% [markdown]
# # **55번**

# %%
def 치즈라면(name = '박태윤'):
  print(name,'물을 끓인다')
  print(name,'면과 소스를 넣는다')
  print(name,'3분이 되면 불을 끈다')
  print(name,'치즈를 올리고 뚜겅을 닫는다')
  print(name,'20초 기다리면 완성')
치즈라면()
# Out:
# 박태윤 물을 끓인다
# 박태윤 면과 소스를 넣는다
# 박태윤 3분이 되면 불을 끈다
# 박태윤 치즈를 올리고 뚜겅을 닫는다
# 박태윤 20초 기다리면 완성

# %% [markdown]
# # **56번**

# %%
def 치즈라면(name ):

  print(name,'물을 끓인다')
  print(name,'면과 소스를 넣는다')
  print(name,'3분이 되면 불을 끈다')
  print(name,'치즈를 올리고 뚜겅을 닫는다')
  print(name,'20초 기다리면 완성')

치즈라면('박세인')
# Out:
# 박세인 물을 끓인다
# 박세인 면과 소스를 넣는다
# 박세인 3분이 되면 불을 끈다
# 박세인 치즈를 올리고 뚜겅을 닫는다
# 박세인 20초 기다리면 완성

# %% [markdown]
# # **57번**

# %%
def 세인세인라면(name,toping):
  print(name, '의 정성')
  print(name,'의 사랑')
  print(name,'의 인규에 대한 믿음')
  print(name,'의 인규에 대한 끈끈함')
  print(name,'의 지민이에 대한',toping)
  print(name,'의 지원이에 대한 사랑')
세인세인라면(input(),input())
# Out:
# 세인이
# 우정
# 세인이 의 정성
# 세인이 의 사랑
# 세인이 의 인규에 대한 믿음
# 세인이 의 인규에 대한 끈끈함
# 세인이 의 지민이에 대한 우정
# 세인이 의 지원이에 대한 사랑

# %%
0227 이시은
0728 이태인
1027 나은유

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7f89c271-db98-4be5-b826-b6f1b51457df" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7f89c271-db98-4be5-b826-b6f1b51457df">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
gray_img = cv2.imread('KakaoTalk_20241203_195402820.png',cv2.IMREAD_GRAYSCALE) # 이미지 읽기 (그레이티브 타입)

print(f"Image shape : {gray_img.shape}") # 이미지 크기 확인 (해상도)
# Out:
# Image shape : (840, 840)

# %%
print(f"Pixel value at (100,200) : {gray_img[200,200]}") # 특정 픽셀 값 확인
# Out:
# Pixel value at (100,200) : 0

# %%
plt.imshow(gray_img,cmap="gray")
plt.show()

# %%
# 컬러 이미지
pixel = [255,0,0] # 빨강 (Red)
pixel = [0,255,0] # 초록 (Green)
pixel = [0,0,255] # 파랑 (Blue)

# 흑백 이미지
pixel = 0   # 검정
pixel = 128 # 그레이
pixel = 255 # 하양

# %%
import numpy as np
import matplotlib.pyplot as plt

# 그레이스케일 이미지 데이터 정의
grayscale_image = np.array([
    [0,128,255,128,0],넹ㅂ
    [50,200,255,200,50],
    [100,255,128,255,100],
    [50,200,255,128,0]
])

# 이미지 시각화
plt.imshow(grayscale_image,cmap='gray')
plt.title('Grayscale lmage')
plt.axis('off') #가로 세로 축 제거
plt.show()
